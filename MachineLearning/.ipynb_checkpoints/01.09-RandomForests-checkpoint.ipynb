# %% [markdown]
# # In-Depth: Decision Trees and Random Forests
# 一个简单的生成分类器(朴素贝叶斯)。 一个强大的鉴别分类器(支持向量机)。 一种叫做随机森林的非参数算法。随机森林是集合方法的一个例子，这意味着它依赖于一个简单估计量集合的结果。使用这种集成方法的结果有些令人惊讶，即总和可能大于部分:也就是说，在许多估计量之间的多数投票结果可能比进行投票的任何单个估计量的结果都好!

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %% [markdown]
# # Motivating Random Forests: Decision Trees
# 随机森林是建立在决策树上的“集成学习器”的一个例子。
# 决策树是对对象进行分类或标记的一种非常直观的方法:您只需询问一系列旨在对分类进行归零处理的问题。
# 二进制分割使得这种方法非常有效:在一个构造良好的树中，每个问题将减少大约一半的选项，即使在大量的类中，也会很快缩小选项的范围。当然，关键在于决定每一步该问哪些问题。在决策树的机器学习实现中，问题通常采用数据按轴对齐的分割形式:即，树中的每个节点使用其中一个特性中的截止值将数据分成两组。

# %% [markdown]
# ## Creating a decision tree

# %%
#建立四部分集群点
from sklearn.datasets import make_blobs

X, y = make_blobs(n_samples=300, centers=4,
                  random_state=0, cluster_std=1.0)#centers指定分成四类，四个标签
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='rainbow');

# %% [markdown]
# 在此数据上构建的简单决策树将根据某种定量标准沿着一个或另一个轴迭代地分割数据，并在每个级别根据其中的多数点数分配新区域的标签。

# %%
#创建决策树分类器
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier().fit(X, y)

# %%
#可视化分类器结果
def visualize_classifier(model, X, y, ax=None, cmap='rainbow'):
    ax = ax or plt.gca()
    
    # Plot the training points
    ax.scatter(X[:, 0], X[:, 1], c=y, s=30, cmap=cmap,
               clim=(y.min(), y.max()), zorder=3)
    ax.axis('tight')
    ax.axis('off')
    xlim = ax.get_xlim()
    ylim = ax.get_ylim()
    
    # fit the estimator
    model.fit(X, y)
    xx, yy = np.meshgrid(np.linspace(*xlim, num=200),
                         np.linspace(*ylim, num=200))
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)

    # Create a color plot with the results
    n_classes = len(np.unique(y))
    contours = ax.contourf(xx, yy, Z, alpha=0.3,
                           levels=np.arange(n_classes + 1) - 0.5,
                           cmap=cmap,
                           zorder=1)

    ax.set(xlim=xlim, ylim=ylim)

# %%
#验证决策树结果
visualize_classifier(DecisionTreeClassifier(), X, y)

# %%
# helpers_05_08 is found in the online appendix
import helpers_05_08
helpers_05_08.plot_tree_interactive(X, y);
# Out:
# interactive(children=(Dropdown(description='depth', index=1, options=(1, 5), value=5), Output()), _dom_classes…

# %% [markdown]
# 注意，随着深度的增加，我们往往会得到非常奇怪的分类区域;例如，在深度为5的地方，在黄色和蓝色区域之间有一个细长的紫色区域。很明显，这不是真实的、固有的数据分布的结果，而是数据的特定采样或噪声特性的结果。也就是说，这个决策树，即使只有5个深度，也明显过度拟合了我们的数据。

# %% [markdown]
# ## Decision trees and over-fitting
# 这种过度拟合是决策树的一个普遍特性:很容易深入到树的深处，从而拟合特定数据的细节，而不是它们所根据的分布的总体特性。观察这种过度拟合的另一种方法是观察在数据的不同子集上训练的模型。

# %%
# helpers_05_08 is found in the online appendix
import helpers_05_08
helpers_05_08.randomized_tree_interactive(X, y)
# Out:
# interactive(children=(Dropdown(description='random_state', options=(0, 100), value=0), Output()), _dom_classes…

# %% [markdown]
# # Ensembles of Estimators: Random Forests
# 多个过拟合估计值可以组合在一起以减少这种过拟合的影响，这是一种称为bagging的集成方法的基础。Bagging利用并行估计器的集合(可能是一个大袋子)，每个估计器都对数据进行过度拟合，并对结果求平均值以找到更好的分类。随机决策树的集合称为随机森林。

# %%
#使用BaggingClassifier解决过拟合的结果
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier

tree = DecisionTreeClassifier()
bag = BaggingClassifier(tree, n_estimators=100, max_samples=0.8,
                        random_state=1)

bag.fit(X, y)
visualize_classifier(bag, X, y)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, random_state=0)
visualize_classifier(model, X, y);

# %% [markdown]
# 我们发现，通过对100多个随机扰动模型进行平均，我们得到了一个更接近我们直觉的整体模型，即参数空间应该如何分割。

# %% [markdown]
# # Random Forest Regression

# %%
rng = np.random.RandomState(42)
x = 10 * rng.rand(200)

def model(x, sigma=0.3):
    fast_oscillation = np.sin(5 * x)
    slow_oscillation = np.sin(0.5 * x)
    noise = sigma * rng.randn(len(x))

    return slow_oscillation + fast_oscillation + noise

y = model(x)
plt.errorbar(x, y, 0.3, fmt='o');

# %%
#随机数用于回归
from sklearn.ensemble import RandomForestRegressor
forest = RandomForestRegressor(200)
forest.fit(x[:, None], y)

xfit = np.linspace(0, 10, 1000)
yfit = forest.predict(xfit[:, None])
ytrue = model(xfit, sigma=0)

plt.errorbar(x, y, 0.3, fmt='o', alpha=0.5)
plt.plot(xfit, yfit, '-r');
plt.plot(xfit, ytrue, '-k', alpha=0.5);

# %% [markdown]
# 这里真实的模型显示为平滑的灰色曲线，而随机森林模型显示为锯齿状的红色曲线。正如您所看到的，非参数随机森林模型具有足够的灵活性来适应多周期数据，而不需要指定多周期模型!

# %% [markdown]
# # Example: Random Forest for Classifying Digits

# %%
from sklearn.datasets import load_digits
digits = load_digits()
digits.keys()
# Out:
# dict_keys(['data', 'target', 'target_names', 'images', 'DESCR'])

# %%
# set up the figure
fig = plt.figure(figsize=(6, 6))  # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

# plot the digits: each image is 8x8 pixels
for i in range(64):
    ax = fig.add_subplot(8, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(digits.images[i], cmap=plt.cm.binary, interpolation='nearest')
    
    # label the image with the target value
    ax.text(0, 7, str(digits.target[i]))

# %%
#使用随机树进行分类
from sklearn.model_selection import train_test_split

Xtrain, Xtest, ytrain, ytest = train_test_split(digits.data, digits.target,
                                                random_state=0)
model = RandomForestClassifier(n_estimators=1000)
model.fit(Xtrain, ytrain)
ypred = model.predict(Xtest)

# %%
from sklearn import metrics
print(metrics.classification_report(ypred, ytest))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99        38
#            1       1.00      0.98      0.99        44
#            2       0.95      1.00      0.98        42
#            3       0.98      0.96      0.97        46
#            4       0.97      1.00      0.99        37
#            5       0.98      0.98      0.98        48
#            6       1.00      1.00      1.00        52
#            7       1.00      0.96      0.98        50
#            8       0.94      0.98      0.96        46
#            9       0.98      0.98      0.98        47
#
#     accuracy                           0.98       450
#    macro avg       0.98      0.98      0.98       450
# weighted avg       0.98      0.98      0.98       450

# %%
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(ytest, ypred)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.ylim([10,0])
plt.xlabel('true label')
plt.ylabel('predicted label');

# %% [markdown]
# # Summary of Random Forests
# 由于基本决策树的简单性，训练和预测都非常快。此外，这两个任务可以直接并行化，因为各个树是完全独立的实体。
# 多个树允许概率分类:估计器之间的多数投票给出了概率的估计(在Scikit-Learn中使用' ' predict_proba() ' '方法访问)。
# 非参数模型是非常灵活的，因此可以很好地完成其他估计器不适合的任务。
# 随机森林的一个主要缺点是结果不容易解释:也就是说，如果你想对分类模型的“意义”得出结论，随机森林可能不是最好的选择。
